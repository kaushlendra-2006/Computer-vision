# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/im39.jpg")


if img is None:
    print
    img = np.zeros((300, 300, 3), dtype=np.uint8)
    cv2.putText(img, "Image Not Found", (50, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

# Resize to 200x200
resized_img = cv2.resize(img, (200, 200))

cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
import numpy as np

# Suppose image shape = (200, 200, 3)
img_array = np.random.randint(0,255,(200,200,3))

# Reshape into 1D
reshaped = img_array.reshape(-1)
print(reshaped.shape)
# Out:
# (120000,)
